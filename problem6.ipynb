# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.preprocessing import normalize

# %%
tips = pd.read_csv(r"C:\Users\Lenovo\Desktop\seaborn-data\tips.csv")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
features_tip  = tips[['total_bill','size']]

# %%
features_tip
# Out:
#      total_bill  size
# 0         16.99     2
# 1         10.34     3
# 2         21.01     3
# 3         23.68     2
# 4         24.59     4
# ..          ...   ...
# 239       29.03     3
# 240       27.18     2
# 241       22.67     2
# 242       17.82     2
# 243       18.78     2
#
# [244 rows x 2 columns]

# %% [markdown]
# #### Normalization

# %%
norm_tips = normalize(features_tip)
norm_tips
# Out:
# array([[0.99314262, 0.11690908],
#        [0.96039435, 0.27864439],
#        [0.98995892, 0.14135539],
#        [0.99645227, 0.08415982],
#        [0.98702651, 0.16055738],
#        [0.98772176, 0.15622329],
#        [0.97496878, 0.2223418 ],
#        [0.98910842, 0.14718875],
#        [0.99127389, 0.13181834],
#        [0.99096837, 0.13409585],
#        [0.98156063, 0.19115105],
#        [0.99362679, 0.11272   ],
#        [0.99169339, 0.12862431],
#        [0.97724809, 0.21209942],
#        [0.99102835, 0.13365183],
#        [0.99573283, 0.09228293],
#        [0.96032213, 0.27889317],
#        [0.98346168, 0.18111633],
#        [0.98473094, 0.17408325],
#        [0.98961125, 0.14376919],
#        [0.99382951, 0.11091847],
#        [0.99517702, 0.09809532],
#        [0.99205368, 0.12581531],
#        [0.9948912 , 0.10095294],
#        [0.99494732, 0.10039832],
#        [0.97569474, 0.21913414],
#        [0.98899596, 0.14794255],
#        [0.98780711, 0.15568276],
# ...

# %%
norm_df = pd.DataFrame(norm_tips,columns = features_tip.columns)

# %%
norm_df
# Out:
#      total_bill      size
# 0      0.993143  0.116909
# 1      0.960394  0.278644
# 2      0.989959  0.141355
# 3      0.996452  0.084160
# 4      0.987027  0.160557
# ..          ...       ...
# 239    0.994703  0.102794
# 240    0.997304  0.073385
# 241    0.996131  0.087881
# 242    0.993761  0.111533
# 243    0.994377  0.105897
#
# [244 rows x 2 columns]

# %% [markdown]
# #### Standardization

# %%
features_tip
# Out:
#      total_bill  size
# 0         16.99     2
# 1         10.34     3
# 2         21.01     3
# 3         23.68     2
# 4         24.59     4
# ..          ...   ...
# 239       29.03     3
# 240       27.18     2
# 241       22.67     2
# 242       17.82     2
# 243       18.78     2
#
# [244 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
new_tip = scaler.fit_transform(features_tip)

# %%
tips_st = pd.DataFrame(new_tip,columns = features_tip.columns)

# %%
tips_st
# Out:
#      total_bill      size
# 0     -0.314711 -0.600193
# 1     -1.063235  0.453383
# 2      0.137780  0.453383
# 3      0.438315 -0.600193
# 4      0.540745  1.506958
# ..          ...       ...
# 239    1.040511  0.453383
# 240    0.832275 -0.600193
# 241    0.324630 -0.600193
# 242   -0.221287 -0.600193
# 243   -0.113229 -0.600193
#
# [244 rows x 2 columns]

# %%
taxis = pd.read_csv(r"C:\Users\Lenovo\Desktop\seaborn-data\taxis.csv")
taxis
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 0     2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0
# 1     2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0
# 2     2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5
# 3     2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0
# 4     2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0
# ...                   ...                  ...         ...       ...   ...
# 6428  2019-03-31 09:51:53  2019-03-31 09:55:27           1      0.75   4.5
# 6429  2019-03-31 17:38:00  2019-03-31 18:34:23           1     18.74  58.0
# 6430  2019-03-23 22:55:18  2019-03-23 23:14:25           1      4.14  16.0
# 6431  2019-03-04 10:09:25  2019-03-04 10:14:29           1      1.12   6.0
# 6432  2019-03-13 19:31:22  2019-03-13 19:48:02           1      3.85  15.0
#
# ...

# %% [markdown]
# #### Normalization

# %%
taxis_2 = taxis[['fare','distance']]
taxis_2
# Out:
#       fare  distance
# 0      7.0      1.60
# 1      5.0      0.79
# 2      7.5      1.37
# 3     27.0      7.70
# 4      9.0      2.16
# ...    ...       ...
# 6428   4.5      0.75
# 6429  58.0     18.74
# 6430  16.0      4.14
# 6431   6.0      1.12
# 6432  15.0      3.85
#
# [6433 rows x 2 columns]

# %%
norm_taxi = normalize(taxis_2)

# %%
norm_taxi
# Out:
# array([[0.97485851, 0.2228248 ],
#        [0.98774694, 0.15606402],
#        [0.98372268, 0.17969334],
#        ...,
#        [0.96811656, 0.25050016],
#        [0.98302025, 0.18349711],
#        [0.96860408, 0.24860838]])

# %%
new_taxis = pd.DataFrame(norm_taxi,columns = taxis_2.columns)
new_taxis
# Out:
#           fare  distance
# 0     0.974859  0.222825
# 1     0.987747  0.156064
# 2     0.983723  0.179693
# 3     0.961658  0.274251
# 4     0.972387  0.233373
# ...        ...       ...
# 6428  0.986394  0.164399
# 6429  0.951563  0.307453
# 6430  0.968117  0.250500
# 6431  0.983020  0.183497
# 6432  0.968604  0.248608
#
# [6433 rows x 2 columns]

# %% [markdown]
# #### Standardization

# %%
taxis_st = scaler.fit_transform(taxis_2)

# %%
taxis_new = pd.DataFrame(taxis_st,columns = taxis_2.columns)
taxis_new
# Out:
#           fare  distance
# 0    -0.527324 -0.372199
# 1    -0.700471 -0.583821
# 2    -0.484038 -0.432289
# 3     1.204142  1.221502
# 4    -0.354178 -0.225892
# ...        ...       ...
# 6428 -0.743757 -0.594272
# 6429  3.887914  4.105839
# 6430  0.251835  0.291408
# 6431 -0.613898 -0.497605
# 6432  0.165262  0.215642
#
# [6433 rows x 2 columns]

# %%
diamonds = pd.read_csv(r"C:\Users\Lenovo\Desktop\seaborn-data\diamonds.csv")
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamond_2 = diamonds[['carat','price']]
diamond_2
# Out:
#        carat  price
# 0       0.23    326
# 1       0.21    326
# 2       0.23    327
# 3       0.29    334
# 4       0.31    335
# ...      ...    ...
# 53935   0.72   2757
# 53936   0.72   2757
# 53937   0.70   2757
# 53938   0.86   2757
# 53939   0.75   2757
#
# [53940 rows x 2 columns]

# %% [markdown]
# #### standardization

# %%
diamond_st = scaler.fit_transform(diamond_2)
new_diamond = pd.DataFrame(diamond_st,columns = diamond_2.columns)
new_diamond
# Out:
#           carat     price
# 0     -1.198168 -0.904095
# 1     -1.240361 -0.904095
# 2     -1.198168 -0.903844
# 3     -1.071587 -0.902090
# 4     -1.029394 -0.901839
# ...         ...       ...
# 53935 -0.164427 -0.294731
# 53936 -0.164427 -0.294731
# 53937 -0.206621 -0.294731
# 53938  0.130927 -0.294731
# 53939 -0.101137 -0.294731
#
# [53940 rows x 2 columns]

# %%
taxis = pd.read_csv(r"C:\Users\Lenovo\Desktop\seaborn-data\taxis.csv")
taxis
# Out:
#                    pickup              dropoff  passengers  distance  fare  \
# 0     2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0
# 1     2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0
# 2     2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5
# 3     2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0
# 4     2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0
# ...                   ...                  ...         ...       ...   ...
# 6428  2019-03-31 09:51:53  2019-03-31 09:55:27           1      0.75   4.5
# 6429  2019-03-31 17:38:00  2019-03-31 18:34:23           1     18.74  58.0
# 6430  2019-03-23 22:55:18  2019-03-23 23:14:25           1      4.14  16.0
# 6431  2019-03-04 10:09:25  2019-03-04 10:14:29           1      1.12   6.0
# 6432  2019-03-13 19:31:22  2019-03-13 19:48:02           1      3.85  15.0
#
# ...

# %%
taxis_2 = taxis[['distance','fare']]
taxis_2
# Out:
#       distance  fare
# 0         1.60   7.0
# 1         0.79   5.0
# 2         1.37   7.5
# 3         7.70  27.0
# 4         2.16   9.0
# ...        ...   ...
# 6428      0.75   4.5
# 6429     18.74  58.0
# 6430      4.14  16.0
# 6431      1.12   6.0
# 6432      3.85  15.0
#
# [6433 rows x 2 columns]

# %% [markdown]
# #### Standardization

# %%
taxis_st = scaler.fit_transform(taxis_2)
taxis_new = pd.DataFrame(taxis_st,columns = taxis_2.columns)
taxis_new
# Out:
#       distance      fare
# 0    -0.372199 -0.527324
# 1    -0.583821 -0.700471
# 2    -0.432289 -0.484038
# 3     1.221502  1.204142
# 4    -0.225892 -0.354178
# ...        ...       ...
# 6428 -0.594272 -0.743757
# 6429  4.105839  3.887914
# 6430  0.291408  0.251835
# 6431 -0.497605 -0.613898
# 6432  0.215642  0.165262
#
# [6433 rows x 2 columns]

# %%
titanic = pd.read_csv(r"C:\Users\Lenovo\Desktop\seaborn-data\titanic.csv")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic_new = titanic[['age','fare']]
titanic_new
# Out:
#       age     fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %% [markdown]
# #### Standardization

# %%
titanic_st = scaler.fit_transform(titanic_new)
titanic_2 = pd.DataFrame(titanic_st,columns = titanic_new.columns)
titanic_2
# Out:
#           age      fare
# 0   -0.530377 -0.502445
# 1    0.571831  0.786845
# 2   -0.254825 -0.488854
# 3    0.365167  0.420730
# 4    0.365167 -0.486337
# ..        ...       ...
# 886 -0.185937 -0.386671
# 887 -0.737041 -0.044381
# 888       NaN -0.176263
# 889 -0.254825 -0.044381
# 890  0.158503 -0.492378
#
# [891 rows x 2 columns]
