# %%
import pandas as pd
import numpy as np
import statistics

# %%
X = np.array([10,50,60,70,80])
Y = np.array([1,2,3,4,5])
np.cov(X,Y)[0,1]
# Out:
# 40.0

# %%
X = np.array([9,8,7,6,5])
Y = np.array([50,40,30,20,10])
np.cov(X,Y)[0,1]
# Out:
# 25.0

# %%
X = np.array([10,50,60,70,80])
Y = np.array([5,4,3,2,1])
np.cov(X,Y)[0,1]
# Out:
# -40.0

# %%
housing = pd.read_csv(r"C:\Users\Lenovo\Desktop\seaborn-data\housing1.csv.xls")
housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
statistics.covariance(housing['total_rooms'],housing['median_house_value'])
# Out:
# 33772890.18720309

# %%
tips = pd.read_csv(r"C:\Users\Lenovo\Desktop\seaborn-data\tips.csv")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
statistics.covariance(tips['total_bill'],tips['tip'])
# Out:
# 8.323501629224854

# %%
statistics.covariance(tips['total_bill'],tips['size'])
# Out:
# 5.06598343790056

# %%
titanic = pd.read_csv(r"C:\Users\Lenovo\Desktop\seaborn-data\titanic.csv")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic['age'].fillna(titanic['age'].median(),inplace = True)
titanic['fare'].fillna(titanic['fare'].mean(),inplace = True)

statistics.covariance(titanic['age'],titanic['fare'])
# Out:
# 62.55676722782507

# %%
apple = pd.read_csv(r"C:\Users\Lenovo\Documents\apple_quality.csv.xls")
apple
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
# ...

# %%
apple.dropna(subset=['Size','Weight'],inplace = True)

# %%
apple[['Size','Weight']].isna().sum()
# Out:
# Size      0
# Weight    0
# dtype: int64

# %%
statistics.covariance(apple['Size'],apple['Weight'])
# Out:
# -0.010432736750034527

# %%
car = pd.read_csv(r"C:\Users\Lenovo\Documents\Car Data.csv.xls")
car
# Out:
#       Car ID      Brand     Model  Year   Color  Mileage  Price       Location
# 0          1     Toyota     Camry  2018   White    45000  18000    Los Angeles
# 1          2      Honda     Civic  2019    Blue    35000  16000       New York
# 2          3       Ford     Focus  2017  Silver    55000  14000        Chicago
# 3          4  Chevrolet     Cruze  2016     Red    60000  12000          Miami
# 4          5    Hyundai   Elantra  2018   Black    40000  15000  San Francisco
# ...      ...        ...       ...   ...     ...      ...    ...            ...
# 1995    1996    Hyundai  Palisade  2019  Silver    65000  22000  San Francisco
# 1996    1997     Toyota    Sienna  2018     Red    55000  16000         Dallas
# 1997    1998      Honda       Fit  2018    Gray    50000  14000        Atlanta
# 1998    1999       Ford    Fusion  2017   White    55000  19000        Phoenix
# 1999    2000  Chevrolet    Malibu  2016    Blue    30000  23000        Houston
#
# [2000 rows x 8 columns]

# %%
statistics.covariance(car['Price'],car['Mileage'])
# Out:
# -13603064.032016007
